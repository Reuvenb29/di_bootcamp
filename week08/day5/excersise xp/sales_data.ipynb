# %%
# /content/drive/MyDrive/Colab Notebooks/Di Bootcamp files/sales_data.csv

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Di Bootcamp files/sales_data.csv')
print(df.head())
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %% [markdown]
# Excercise 1
#
# **Why is data visualization important?**
# It helps simplify complex data, making trends and outliers easy to spot. It supports better decision-making and clearer communication, especially for non-technical audiences.
#
# **What is a line graph used for?**
# To show trends over time, like daily temperature or monthly sales.

# %% [markdown]
# excersise 2

# %%
import matplotlib.pyplot as plt

days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
temperatures = [72, 74, 76, 80, 82, 78, 75]

plt.plot(days, temperatures, marker='o')
plt.title("Weekly Temperature Variation")
plt.xlabel("Day")
plt.ylabel("Temperature (°F)")
plt.grid(True)
plt.show()

# %% [markdown]
# excersise 3

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May"]
sales = [5000, 5500, 6200, 7000, 7500]

plt.bar(months, sales, color='skyblue')
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.show()

# %% [markdown]
# E4

# %%
# prompt:     Calculate the total quantity of products sold by the company.
#     Identify the category that had the highest revenue and calculate how much revenue it generated.
#     Determine the average revenue per sale in the dataset.
#     Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

import pandas as pd
import matplotlib.pyplot as plt
# Calculate the total quantity of products sold
total_quantity = df['Quantity'].sum()
print(f"\nTotal quantity of products sold: {total_quantity}")

# Identify the category with the highest revenue
df['Revenue'] = df['Quantity'] * df['Price']
category_revenue = df.groupby('Category')['Revenue'].sum()
highest_revenue_category = category_revenue.idxmax()
highest_revenue_amount = category_revenue.max()
print(f"Category with the highest revenue: {highest_revenue_category}")
print(f"Revenue generated by {highest_revenue_category}: ${highest_revenue_amount:.2f}")

# Determine the average revenue per sale
average_revenue_per_sale = df['Revenue'].mean()
print(f"Average revenue per sale: ${average_revenue_per_sale:.2f}")

# Create a bar chart to visualize total revenue by quarter
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Quarter'] = df['Order Date'].dt.quarter
quarterly_revenue = df.groupby('Quarter')['Revenue'].sum()

plt.figure(figsize=(8, 5))
plt.bar(quarterly_revenue.index.astype(str), quarterly_revenue.values, color='lightgreen')
plt.title('Total Revenue by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue ($)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Quantity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d9d09e44e5e3> in <cell line: 0>()
#       7 import matplotlib.pyplot as plt
# ...

# %%
# prompt:     Calculate the total quantity of products sold by the company.
#     Identify the category that had the highest revenue and calculate how much revenue it generated.
#     Determine the average revenue per sale in the dataset.
#     Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

import pandas as pd
import matplotlib.pyplot as plt

# Print the column names to identify the correct quantity column name
print(df.columns)

# Once you have the correct column name for quantity, replace 'Quantity' below with the actual name
# Calculate the total quantity of products sold
# total_quantity = df['Quantity'].sum()
# print(f"\nTotal quantity of products sold: {total_quantity}")

# The rest of the code will likely also have KeyErrors for 'Category', 'Price', and 'Order Date'
# as these columns might also have different names. You will need to inspect the output of
# print(df.columns) and update those column names as well.

# # Identify the category with the highest revenue
# df['Revenue'] = df['Quantity'] * df['Price']
# category_revenue = df.groupby('Category')['Revenue'].sum()
# highest_revenue_category = category_revenue.idxmax()
# highest_revenue_amount = category_revenue.max()
# print(f"Category with the highest revenue: {highest_revenue_category}")
# print(f"Revenue generated by {highest_revenue_category}: ${highest_revenue_amount:.2f}")

# # Determine the average revenue per sale
# average_revenue_per_sale = df['Revenue'].mean()
# print(f"Average revenue per sale: ${average_revenue_per_sale:.2f}")

# # Create a bar chart to visualize total revenue by quarter
# df['Order Date'] = pd.to_datetime(df['Order Date'])
# df['Quarter'] = df['Order Date'].dt.quarter
# quarterly_revenue = df.groupby('Quarter')['Revenue'].sum()

# plt.figure(figsize=(8, 5))
# plt.bar(quarterly_revenue.index.astype(str), quarterly_revenue.values, color='lightgreen')
# plt.title('Total Revenue by Quarter')
# plt.xlabel('Quarter')
# plt.ylabel('Total Revenue ($)')
# plt.show()
# Out:
# Index(['date', 'product', 'category', 'price', 'quantity', 'revenue'], dtype='object')

# %% [markdown]
# E5

# %%
import numpy as np

x = np.arange(-10, 11)
y = x ** 2

plt.plot(x, y, marker='o')
plt.title("Plot of y = x²")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %%
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]

plt.bar(products, sales, color='green')
plt.title("Product Sales in a Week")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['red', 'yellow', 'pink', 'brown']

plt.pie(percentages, labels=fruits, colors=colors, autopct='%1.1f%%')
plt.title("Favorite Fruits Distribution")
plt.legend(fruits)
plt.show()

# %%
from google.colab import files

# Provide the full path to the file in your Google Drive
files.download('/content/drive/MyDrive/Colab Notebooks/Di Bootcamp files/sales_data.csv')
