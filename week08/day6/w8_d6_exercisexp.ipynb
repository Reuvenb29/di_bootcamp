# %% [markdown]
# Exercise 1

# %% [markdown]
# Data visualization is a crucial part of data analysis because it helps us understand complex datasets by presenting them in a visual format. This makes it easier to identify patterns, trends, and outliers that might not be obvious in raw data.
#
# A line graph is a type of data visualization used to display how something changes over time or across a continuous range. It connects data points with lines, making it easy to see trends, increases, decreases, and volatility. It is particularly useful for showing trends in data over time, such as stock prices, temperature changes, or population growth.

# %% [markdown]
# Exercise 2

# %%
import matplotlib.pyplot as plt

# Temperature data for a week
temperatures = [72, 74, 76, 80, 82, 78, 75]
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Create the line plot
plt.plot(days, temperatures)

# Label the axes
plt.xlabel("Day")
plt.ylabel("Temperature (°F)")

# Add a title to the plot
plt.title("Weekly Temperature Variations")

# Display the plot
plt.show()

# %% [markdown]
# Exercise 3

# %%
import matplotlib.pyplot as plt

# Monthly sales data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [5000, 5500, 6200, 7000, 7500]

# Create the bar chart
plt.bar(months, sales)

# Label the axes
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")

# Add a title to the chart
plt.title("Monthly Sales Data")

# Display the chart
plt.show()

# %% [markdown]
# Exercise 4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df_sales = pd.read_csv('/content/drive/MyDrive/di_bootcamp_resources/week_8/sales_data.csv')
display(df_sales.head())
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
total_quantity_sold = df_sales['quantity'].sum()
print(f"The total quantity of products sold is: {total_quantity_sold}")
# Out:
# The total quantity of products sold is: 5360.0

# %%
category_revenue = df_sales.groupby('category')['revenue'].sum()
highest_revenue_category = category_revenue.idxmax()
highest_revenue_amount = category_revenue.max()

print(f"The category with the highest revenue is '{highest_revenue_category}' with a total revenue of ${highest_revenue_amount:.2f}")
# Out:
# The category with the highest revenue is 'Electronics' with a total revenue of $516080.00

# %%
average_revenue_per_sale = df_sales['revenue'].mean()
print(f"The average revenue per sale is: ${average_revenue_per_sale:.2f}")
# Out:
# The average revenue per sale is: $2060.68

# %% [markdown]
# # Task
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4) using the data from "/content/drive/MyDrive/di_bootcamp_resources/week_8/sales_data.csv".

# %% [markdown]
# ## Convert date column to datetime
#
# ### Subtask:
# Ensure the 'date' column is in datetime format for easier extraction of the quarter.

# %% [markdown]
# **Reasoning**:
# Convert the 'date' column to datetime format to extract the quarter information.

# %%
df_sales['date'] = pd.to_datetime(df_sales['date'])
display(df_sales.head())
# Out:
#         date     product     category   price  quantity  revenue
# 0 2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1 2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2 2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3 2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4 2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %% [markdown]
# ## Extract quarter
#
# ### Subtask:
# Create a new column for the quarter based on the 'date' column.

# %% [markdown]
# **Reasoning**:
# Create a new column 'quarter' by extracting the quarter from the 'date' column and display the updated DataFrame.

# %%
df_sales['quarter'] = df_sales['date'].dt.quarter
display(df_sales.head())
# Out:
#         date     product     category   price  quantity  revenue  quarter
# 0 2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0        1
# 1 2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0        1
# 2 2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0        1
# 3 2022-01-03  Headphones  Electronics   100.0      20.0   2000.0        1
# 4 2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0        1

# %% [markdown]
# ## Calculate quarterly revenue
#
# ### Subtask:
# Group the data by the new 'quarter' column and calculate the sum of 'revenue' for each quarter.

# %% [markdown]
# **Reasoning**:
# Group the dataframe by quarter and calculate the sum of revenue for each quarter.

# %%
quarterly_revenue = df_sales.groupby('quarter')['revenue'].sum()
display(quarterly_revenue)
# Out:
# quarter
# 1    182100.0
# 2    183970.0
# 3    197680.0
# 4    194580.0
# Name: revenue, dtype: float64

# %% [markdown]
# ## Create bar chart
#
# ### Subtask:
# Generate a bar chart using the calculated quarterly revenue, labeling the axes and adding a title.

# %% [markdown]
# **Reasoning**:
# Generate a bar chart using the calculated quarterly revenue, labeling the axes and adding a title.

# %%
import matplotlib.pyplot as plt

plt.bar(quarterly_revenue.index, quarterly_revenue.values)
plt.xlabel("Quarter")
plt.ylabel("Total Revenue ($)")
plt.title("Quarterly Revenue")
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * The total revenue for each quarter was calculated: Q1 had \$182,100.0, Q2 had \$183,970.0, Q3 had \$197,680.0, and Q4 had \$194,580.0.
# * Q3 generated the highest revenue at \$197,680.0.
# * Q1 generated the lowest revenue at \$182,100.0.
#
# ### Insights or Next Steps
#
# * Analyze the factors contributing to the higher revenue in Q3 and Q4 compared to Q1 and Q2.
# * Investigate potential seasonality in sales data and its impact on quarterly revenue.

# %% [markdown]
# Exercise 5

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate x values from -10 to 10
x = np.linspace(-10, 10, 100)

# Calculate y values
y = x**2

# Create the line plot
plt.plot(x, y)

# Add title and labels
plt.title("Plot of y = x^2")
plt.xlabel("x")
plt.ylabel("y")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sales data for four products
products = ['A', 'B', 'C', 'D']
sales = [15, 30, 45, 20]

# Create the bar chart
plt.bar(products, sales)

# Add title and labels
plt.title("Weekly Sales Data for Products A, B, C, D")
plt.xlabel("Product")
plt.ylabel("Sales")

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for favorite fruits
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['red', 'yellow', 'purple', 'brown']

# Create the pie chart
plt.figure(figsize=(8, 8)) # Set the size of the pie chart
plt.pie(percentages, labels=fruits, colors=colors, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title("Favorite Fruits Distribution")

# Add a legend
plt.legend(fruits, loc="best")

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Display the chart
plt.show()
